# %% [markdown]
# # Utils
#
# > Various useful pieces

# %%
#| default_exp utils

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export

import os

# %%
#| export

# %%
#| hide
import nbdev; nbdev.nbdev_export()
